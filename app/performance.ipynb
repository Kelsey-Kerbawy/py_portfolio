# %%
import pandas as pd
from data_capture import FromYF
import inputs
from pypfopt.expected_returns import returns_from_prices
from core.performance import cumulative_returns, hypothesis_test
from core.statistics import population_stats, sample_stats

# %%
watchlist_df = pd.read_excel(inputs.WATCHLIST_PATH,index_col=0)
watchlist = watchlist_df.index.tolist()
watchlist.append(inputs.MARKET)

price_df = FromYF.get_prices(watchlist,period=inputs.PERIOD,interval=inputs.INTERVAL)

returns_df = returns_from_prices(price_df,log_returns=inputs.IS_CONTINOUSLY_COMPOUNDED)

returns_df
# Out:
# [*********************100%***********************]  12 of 12 completed
#                  BLX      CSIQ      CWEN        ED      ENPH      FSLR  \
# Date
# 2021-03-11  0.003016  0.083795  0.011299 -0.007816  0.084695  0.069995
# 2021-03-12 -0.004209 -0.020660 -0.002793  0.016041 -0.003810  0.011479
# 2021-03-15  0.008454 -0.024793  0.009454  0.012405  0.057374  0.007078
# 2021-03-16 -0.009581 -0.051740 -0.017690  0.003620 -0.045074 -0.000848
# 2021-03-17  0.001209 -0.026341 -0.048729 -0.004023 -0.014972 -0.028135
# ...              ...       ...       ...       ...       ...       ...
# 2023-03-03  0.000000  0.021032  0.022911  0.012052  0.026470  0.059984
# 2023-03-06  0.016199  0.022994 -0.008833  0.010365  0.037714  0.010423
# 2023-03-07  0.013815 -0.003512 -0.004774 -0.010586 -0.005059  0.009373
# 2023-03-08 -0.034067  0.000940 -0.002558  0.011361 -0.026315  0.000187
# 2023-03-09 -0.025502 -0.027934 -0.021161 -0.004363 -0.011268 -0.014370
#
#                 GPRE      MAXN       ORA       REX      SEDG      ^RUA
# Date
# 2021-03-11  0.030815  0.130239  0.018804 -0.005472  0.055637  0.012878
# 2021-03-12  0.009843 -0.007947  0.002293 -0.035371 -0.012702  0.001374
# 2021-03-15 -0.018051  0.068091 -0.037058 -0.035944  0.019658  0.007085
# 2021-03-16 -0.044118 -0.038000 -0.023043 -0.064425 -0.039063 -0.003661
# 2021-03-17  0.019231 -0.038202 -0.033678  0.018069  0.020413  0.003177
# ...              ...       ...       ...       ...       ...       ...
# 2023-03-03  0.020444  0.045810  0.009024  0.020796  0.010543  0.016014
# 2023-03-06 -0.041786  0.022436  0.012383 -0.047535  0.017287 -0.001377
# 2023-03-07 -0.014038 -0.020376 -0.008959 -0.000930 -0.012362 -0.014719
# 2023-03-08  0.010603  0.440000 -0.002861  0.001862 -0.010476  0.001223
# 2023-03-09 -0.023681  0.011852 -0.000803 -0.017653 -0.035084 -0.020017
#
# [501 rows x 12 columns]

# %%
cum_returns_df = cumulative_returns(returns_df)

cum_returns_df
# Out:
#                  BLX      CSIQ      CWEN        ED      ENPH      FSLR  \
# Date
# 2021-03-11  1.003016  1.083795  1.011299  0.992184  1.084695  1.069995
# 2021-03-12  0.998794  1.061404  1.008475  1.008100  1.080562  1.082277
# 2021-03-15  1.007238  1.035088  1.018009  1.020605  1.142557  1.089937
# 2021-03-16  0.997587  0.981533  1.000000  1.024300  1.091058  1.089012
# 2021-03-17  0.998794  0.955679  0.951271  1.020179  1.074723  1.058373
# ...              ...       ...       ...       ...       ...       ...
# 2023-03-03  1.249483  0.963758  1.217663  1.386635  1.424654  2.774828
# 2023-03-06  1.269723  0.985919  1.206908  1.401007  1.478384  2.803751
# 2023-03-07  1.287264  0.982456  1.201146  1.386176  1.470905  2.830032
# 2023-03-08  1.243411  0.983379  1.198073  1.401925  1.432198  2.830560
# 2023-03-09  1.211701  0.955910  1.172721  1.395809  1.416060  2.789884
#
#                 GPRE      MAXN       ORA       REX      SEDG      ^RUA
# Date
# 2021-03-11  1.030815  1.130239  1.018804  0.994528  1.055637  1.012878
# 2021-03-12  1.040962  1.121257  1.021140  0.959350  1.042228  1.014270
# 2021-03-15  1.022172  1.197605  0.983298  0.924867  1.062717  1.021455
# 2021-03-16  0.977076  1.152096  0.960640  0.865283  1.021204  1.017716
# 2021-03-17  0.995866  1.108084  0.928288  0.880917  1.042049  1.020949
# ...              ...       ...       ...       ...       ...       ...
# 2023-03-03  1.313040  0.560479  1.029831  0.882567  1.168627  1.000885
# 2023-03-06  1.258174  0.573054  1.042583  0.840615  1.188830  0.999507
# 2023-03-07  1.240511  0.561377  1.033243  0.839833  1.174134  0.984795
# 2023-03-08  1.253664  0.808383  1.030287  0.841397  1.161834  0.985999
# 2023-03-09  1.223976  0.817964  1.029459  0.826544  1.121071  0.966262
#
# [501 rows x 12 columns]

# %%
population_stats_df = population_stats(returns_df)
sample_stats_df = sample_stats(returns_df,inputs.SAMPLE_START)

hypothesis_df = hypothesis_test(sample_stats_df,population_stats_df)

hypothesis_df
# Out:
#       samplereject
# BLX          False
# CSIQ         False
# CWEN         False
# ED           False
# ENPH         False
# FSLR         False
# GPRE         False
# MAXN         False
# ORA          False
# REX          False
# SEDG         False
# ^RUA         False
